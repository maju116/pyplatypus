# %% [markdown]
# # The data
# This notebook aims at presenting the process of creating the end-to-end modelling pipeline with the use of [PyPlatypus](https://github.com/maju116/pyplatypus) package.
#
# As starting point, the data is crucial, let's proceed with gathering it hence. We will be working with the nuclei-related images of which the [2018 Data Science Bowl dataset](https://www.kaggle.com/c/data-science-bowl-2018/data) is composed. These are PNG files organized in accordance with the following structure:
#
# stage1_data
#
# ----|image_name
#
# --------|images
#
# ------------|image.png
#
# --------|masks
#
# ------------|mask1.png
#
# ------------|mask2.png
#
# In the "images" folder you will find an image of shape (256, 256, 4) with the values varying from 0 to 1, while the masks are just (256, 256) matrices with the values coming from the discrete set: {0, 1}.

# %% [markdown]
# # The preparation
# After downloading the data, unpack it and move to any preferred destination. For this example we will be interested only in stage1_train and stage1_test subdirectories, thus other files could be put aside. Let's take a look at the exemplary image.

# %%
from pathlib import Path
import os
cwd = Path.cwd()
while cwd.stem != "pyplatypus":
    cwd = cwd.parent
os.chdir(cwd)

# %%
# 20% for validation
data_path = Path("examples/data/data_science_bowl/")
models_path = Path("examples/models/")

example = "0a7d30b252359a10fd298b638b90cb9ada3acced4e0c0e5a3692013f432ee4e9"
train_image = os.listdir(data_path/Path(f"stage1_train/{example}/images"), )
train_masks = os.listdir(data_path/Path(f"stage1_train/{example}/masks"))

# %%
from matplotlib import pyplot as plt
# Load the image along with on of the masks associated
example_image = plt.imread(data_path/Path(f"stage1_train/{example}/images/{train_image[0]}"))
example_mask1 = plt.imread(data_path/Path(f"stage1_train/{example}/masks/{train_masks[0]}"))
example_mask2 = plt.imread(data_path/Path(f"stage1_train/{example}/masks/{train_masks[2]}"))

# %%
plt.figure()
plt.imshow(example_image, alpha=0.6)
plt.imshow(example_mask1, alpha=0.2)
plt.imshow(example_mask2, alpha=0.2)
plt.title("Original image with the masks in yellow.")
# Out:
# Text(0.5, 1.0, 'Original image with the masks in yellow.')

# %% [markdown]
# What you see as the yellow area is the "Segmentation mask" which is simply telling us which pixel belongs to which class. Assesing this membership is the goal that we are striving to achieve.

# %% [markdown]
# # Splitting the data
# For the modeling, beside train and test sets, we will need a validation set for it is common good practice to have one.
# Feel free to use the following script but beware, it will move a sample set of images from yout stage1_train folder to the stage1_validation.

# %%
from glob import glob
from random import sample
from shutil import move

def create_validation_set(data_path, p=0.2):
    train_images = glob(str(data_path/Path("stage1_train/*")))
    # Validation set size (as percentage)
    p = 0.2
    validation_images = sample(train_images, round(p*len(train_images)))
    Path.mkdir(data_path/Path("stage1_validation"))
    for img_path in validation_images:
        trimmed_path = Path(img_path).stem
        move(img_path, str(data_path/Path(f"stage1_validation/{trimmed_path}")))

# %% [markdown]
# Let's now inspect the input message that we are to send to PlatypusSolver in order to run it.

# %%
import yaml
import json
with open(r"examples/data_science_bowl_config.yaml") as stream:
    config = yaml.safe_load(stream)
    print(json.dumps(config, indent=4, sort_keys=True))
# Out:
# {
#     "augmentation": {
#         "Blur": {
#             "always_apply": false,
#             "blur_limit": 7,
#             "p": 0.5
#         },
#         "Flip": {
#             "always_apply": false,
#             "p": 0.5
#         },
#         "RandomRotate90": {
#             "always_apply": false,
#             "p": 0.5
#         },
#         "ToFloat": {
#             "always_apply": true,
#             "max_value": 255,
#             "p": 1.0
#         }
#     },
#     "object_detection": null,
#     "semantic_segmentation": {
#         "data": {
#             "colormap": [
#                 [
#                     0,
#                     0,
#                     0
#                 ],
#                 [
#                     255,
#                     255,
#                     255
#                 ]
#             ],
#             "column_sep": ";",
#             "loss": "focal loss",
#             "metrics": [
#                 "tversky coefficient",
#                 "iou coefficient"
#             ],
#             "mode": "nested_dirs",
#             "optimizer": "adam",
#             "shuffle": false,
#             "subdirs": [
#                 "images",
#                 "masks"
#             ],
#             "test_path": "examples/data/data_science_bowl/stage1_test",
#             "train_path": "examples/data/data_science_bowl/stage1_train",
#             "validation_path": "examples/data/data_science_bowl/stage1_validation"
#         },
#         "models": [
#             {
#                 "activation_layer": "relu",
#                 "batch_normalization": true,
#                 "batch_size": 32,
#                 "blocks": 4,
#                 "deep_supervision": false,
#                 "dropout": 0.2,
#                 "epochs": 100,
#                 "filters": 16,
#                 "grayscale": false,
#                 "h_splits": 0,
#                 "kernel_initializer": "he_normal",
#                 "linknet": false,
#                 "n_class": 2,
#                 "name": "res_u_net",
#                 "net_h": 256,
#                 "net_w": 256,
#                 "plus_plus": false,
#                 "resunet": true,
#                 "u_net_conv_block_width": 4,
#                 "use_separable_conv2d": true,
#                 "use_spatial_droput2d": true,
#                 "use_up_sampling2d": false,
#                 "w_splits": 0
#             },
#             {
#                 "batch_normalization": true,
#                 "batch_size": 8,
#                 "blocks": 2,
#                 "deep_supervision": false,
#                 "dropout": 0.2,
#                 "epochs": 100,
#                 "filters": 16,
#                 "grayscale": false,
#                 "h_splits": 0,
#                 "kernel_initializer": "he_normal",
#                 "linknet": false,
#                 "n_class": 2,
#                 "name": "u_net_plus_plus",
#                 "net_h": 256,
#                 "net_w": 256,
#                 "plus_plus": true,
#                 "use_separable_conv2d": true,
#                 "use_spatial_dropout2d": true,
#                 "use_up_sampling2d": true,
#                 "w_splits": 0
#             }
#         ]
#     }
# }

# %% [markdown]
# What might have struck you is that the config is organized so that it might potentially tell the Solver to train multiple models while using a complex augmentation pipeline and loss functions coming from the rather large set of ones available within the PyPlatypus framework.

# %% [markdown]
# ![68747470733a2f2f69322e77702e636f6d2f6e657074756e652e61692f77702d636f6e74656e742f75706c6f6164732f552d6e65742d6172636869746563747572652e706e673f73736c3d31.webp](attachment:68747470733a2f2f69322e77702e636f6d2f6e657074756e652e61692f77702d636f6e74656e742f75706c6f6164732f552d6e65742d6172636869746563747572652e706e673f73736c3d31.webp)

# %% [markdown]
# # The model
#
# The models present in the PyPlatypus segmentation submodule are U-Net based.
#
# U-Net was originally developed for biomedical data segmentation. As you can see in the picture above architecture is very similar to autoencoder and it looks like the letter U, hence the name. Model is composed of 2 parts, and each part has some number of convolutional blocks (3 in the image above). Number of blocks will be hyperparameter in our model.
#
# To build a U-Net model in platypus use u_net function. You have to specify:
#
# * Number of convolutional blocks,
# * Input image height and width - it need not to be in the form 2^N, as we added the generalizng layer.
# * Indicator determining if the input image will be loaded as grayscale or RGB.
# * Number of classes - in our case we have only 2 (background and nuclei).
# * Additional arguments for CNN such as: number of filters, dropout rate etc.
#
# Hereafter the models' building process is rather straightforward.

# %%
from platypus.solvers.platypus_cv_solver import PlatypusSolver


ps = PlatypusSolver(
    config_yaml_path=Path("examples/data_science_bowl_config.yaml")
)
ps.train()
# Out:
# 536 images detected!
# Set 'steps_per_epoch' to: 17
# 134 images detected!
# Set 'steps_per_epoch' to: 5
# 134 images detected!
# Set 'steps_per_epoch' to: 5
# 2022-09-27 12:29:23.944424: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:23.953642: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:23.953966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:23.959581: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-27 12:29:23.960378: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:23.960688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:23.960905: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:24.442667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:24.442943: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:24.443099: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-27 12:29:24.443214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7030 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1
# Epoch 1/100
# 2022-09-27 12:29:32.545612: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 17/17 [==============================] - 47s 2s/step - loss: 0.1463 - tversky_coefficient: 0.5225 - categorical_crossentropy: 0.6720 - iou_coefficient: 0.3539 - val_loss: 0.1461 - val_tversky_coefficient: 0.5011 - val_categorical_crossentropy: 0.7013 - val_iou_coefficient: 0.3344
# Epoch 2/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.1044 - tversky_coefficient: 0.5623 - categorical_crossentropy: 0.5887 - iou_coefficient: 0.3913 - val_loss: 0.1518 - val_tversky_coefficient: 0.4892 - val_categorical_crossentropy: 0.7173 - val_iou_coefficient: 0.3238
# Epoch 3/100
# 17/17 [==============================] - 36s 2s/step - loss: 0.0809 - tversky_coefficient: 0.6115 - categorical_crossentropy: 0.5100 - iou_coefficient: 0.4405 - val_loss: 0.2693 - val_tversky_coefficient: 0.4141 - val_categorical_crossentropy: 0.8949 - val_iou_coefficient: 0.2613
# Epoch 4/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0673 - tversky_coefficient: 0.6430 - categorical_crossentropy: 0.4611 - iou_coefficient: 0.4740 - val_loss: 0.0882 - val_tversky_coefficient: 0.5995 - val_categorical_crossentropy: 0.5349 - val_iou_coefficient: 0.4282
# Epoch 5/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0588 - tversky_coefficient: 0.6689 - categorical_crossentropy: 0.4231 - iou_coefficient: 0.5025 - val_loss: 0.1134 - val_tversky_coefficient: 0.5853 - val_categorical_crossentropy: 0.5773 - val_iou_coefficient: 0.4142
# Epoch 6/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0495 - tversky_coefficient: 0.6873 - categorical_crossentropy: 0.3934 - iou_coefficient: 0.5237 - val_loss: 0.0854 - val_tversky_coefficient: 0.6322 - val_categorical_crossentropy: 0.4923 - val_iou_coefficient: 0.4625
# Epoch 7/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0442 - tversky_coefficient: 0.7089 - categorical_crossentropy: 0.3635 - iou_coefficient: 0.5491 - val_loss: 0.0880 - val_tversky_coefficient: 0.6514 - val_categorical_crossentropy: 0.4716 - val_iou_coefficient: 0.4833
# Epoch 8/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0417 - tversky_coefficient: 0.7206 - categorical_crossentropy: 0.3475 - iou_coefficient: 0.5633 - val_loss: 0.0911 - val_tversky_coefficient: 0.6679 - val_categorical_crossentropy: 0.4548 - val_iou_coefficient: 0.5018
# Epoch 9/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0378 - tversky_coefficient: 0.7330 - categorical_crossentropy: 0.3295 - iou_coefficient: 0.5786 - val_loss: 0.0983 - val_tversky_coefficient: 0.6881 - val_categorical_crossentropy: 0.4371 - val_iou_coefficient: 0.5249
# Epoch 10/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0337 - tversky_coefficient: 0.7503 - categorical_crossentropy: 0.3057 - iou_coefficient: 0.6004 - val_loss: 0.1043 - val_tversky_coefficient: 0.7018 - val_categorical_crossentropy: 0.4262 - val_iou_coefficient: 0.5411
# Epoch 11/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0319 - tversky_coefficient: 0.7603 - categorical_crossentropy: 0.2926 - iou_coefficient: 0.6134 - val_loss: 0.1154 - val_tversky_coefficient: 0.7214 - val_categorical_crossentropy: 0.4133 - val_iou_coefficient: 0.5649
# Epoch 12/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0300 - tversky_coefficient: 0.7674 - categorical_crossentropy: 0.2825 - iou_coefficient: 0.6227 - val_loss: 0.1172 - val_tversky_coefficient: 0.7251 - val_categorical_crossentropy: 0.4116 - val_iou_coefficient: 0.5696
# Epoch 13/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0290 - tversky_coefficient: 0.7741 - categorical_crossentropy: 0.2740 - iou_coefficient: 0.6315 - val_loss: 0.1248 - val_tversky_coefficient: 0.7364 - val_categorical_crossentropy: 0.4044 - val_iou_coefficient: 0.5836
# Epoch 14/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0272 - tversky_coefficient: 0.7796 - categorical_crossentropy: 0.2659 - iou_coefficient: 0.6388 - val_loss: 0.1413 - val_tversky_coefficient: 0.7565 - val_categorical_crossentropy: 0.3964 - val_iou_coefficient: 0.6093
# Epoch 15/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0285 - tversky_coefficient: 0.7839 - categorical_crossentropy: 0.2624 - iou_coefficient: 0.6446 - val_loss: 0.1677 - val_tversky_coefficient: 0.7798 - val_categorical_crossentropy: 0.3942 - val_iou_coefficient: 0.6403
# Epoch 16/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0290 - tversky_coefficient: 0.7894 - categorical_crossentropy: 0.2569 - iou_coefficient: 0.6521 - val_loss: 0.1404 - val_tversky_coefficient: 0.7565 - val_categorical_crossentropy: 0.3948 - val_iou_coefficient: 0.6092
# Epoch 17/100
# 17/17 [==============================] - 36s 2s/step - loss: 0.0270 - tversky_coefficient: 0.7945 - categorical_crossentropy: 0.2491 - iou_coefficient: 0.6592 - val_loss: 0.1473 - val_tversky_coefficient: 0.7628 - val_categorical_crossentropy: 0.3935 - val_iou_coefficient: 0.6175
# Epoch 18/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0255 - tversky_coefficient: 0.7956 - categorical_crossentropy: 0.2462 - iou_coefficient: 0.6607 - val_loss: 0.1888 - val_tversky_coefficient: 0.7935 - val_categorical_crossentropy: 0.3971 - val_iou_coefficient: 0.6589
# Epoch 19/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0249 - tversky_coefficient: 0.8028 - categorical_crossentropy: 0.2379 - iou_coefficient: 0.6707 - val_loss: 0.1756 - val_tversky_coefficient: 0.7859 - val_categorical_crossentropy: 0.3936 - val_iou_coefficient: 0.6485
# Epoch 20/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0232 - tversky_coefficient: 0.8058 - categorical_crossentropy: 0.2326 - iou_coefficient: 0.6748 - val_loss: 0.1708 - val_tversky_coefficient: 0.7860 - val_categorical_crossentropy: 0.3904 - val_iou_coefficient: 0.6488
# Epoch 21/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0228 - tversky_coefficient: 0.8132 - categorical_crossentropy: 0.2239 - iou_coefficient: 0.6853 - val_loss: 0.1835 - val_tversky_coefficient: 0.7941 - val_categorical_crossentropy: 0.3921 - val_iou_coefficient: 0.6599
# Epoch 22/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0242 - tversky_coefficient: 0.8122 - categorical_crossentropy: 0.2265 - iou_coefficient: 0.6838 - val_loss: 0.1762 - val_tversky_coefficient: 0.7898 - val_categorical_crossentropy: 0.3903 - val_iou_coefficient: 0.6539
# Epoch 23/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0225 - tversky_coefficient: 0.8123 - categorical_crossentropy: 0.2246 - iou_coefficient: 0.6840 - val_loss: 0.1738 - val_tversky_coefficient: 0.7920 - val_categorical_crossentropy: 0.3860 - val_iou_coefficient: 0.6570
# Epoch 24/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0229 - tversky_coefficient: 0.8136 - categorical_crossentropy: 0.2236 - iou_coefficient: 0.6858 - val_loss: 0.2062 - val_tversky_coefficient: 0.8074 - val_categorical_crossentropy: 0.3990 - val_iou_coefficient: 0.6786
# Epoch 25/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0219 - tversky_coefficient: 0.8197 - categorical_crossentropy: 0.2155 - iou_coefficient: 0.6945 - val_loss: 0.2194 - val_tversky_coefficient: 0.8170 - val_categorical_crossentropy: 0.4019 - val_iou_coefficient: 0.6924
# Epoch 26/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0204 - tversky_coefficient: 0.8245 - categorical_crossentropy: 0.2090 - iou_coefficient: 0.7015 - val_loss: 0.1517 - val_tversky_coefficient: 0.7962 - val_categorical_crossentropy: 0.3625 - val_iou_coefficient: 0.6628
# Epoch 27/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0215 - tversky_coefficient: 0.8291 - categorical_crossentropy: 0.2051 - iou_coefficient: 0.7081 - val_loss: 0.1536 - val_tversky_coefficient: 0.7972 - val_categorical_crossentropy: 0.3635 - val_iou_coefficient: 0.6641
# Epoch 28/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0203 - tversky_coefficient: 0.8269 - categorical_crossentropy: 0.2060 - iou_coefficient: 0.7050 - val_loss: 0.1290 - val_tversky_coefficient: 0.7980 - val_categorical_crossentropy: 0.3404 - val_iou_coefficient: 0.6651
# Epoch 29/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0206 - tversky_coefficient: 0.8287 - categorical_crossentropy: 0.2045 - iou_coefficient: 0.7075 - val_loss: 0.0866 - val_tversky_coefficient: 0.7898 - val_categorical_crossentropy: 0.3124 - val_iou_coefficient: 0.6536
# Epoch 30/100
# 17/17 [==============================] - 44s 3s/step - loss: 0.0201 - tversky_coefficient: 0.8294 - categorical_crossentropy: 0.2031 - iou_coefficient: 0.7086 - val_loss: 0.1246 - val_tversky_coefficient: 0.8190 - val_categorical_crossentropy: 0.3148 - val_iou_coefficient: 0.6949
# Epoch 31/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0197 - tversky_coefficient: 0.8364 - categorical_crossentropy: 0.1949 - iou_coefficient: 0.7189 - val_loss: 0.0956 - val_tversky_coefficient: 0.8171 - val_categorical_crossentropy: 0.2911 - val_iou_coefficient: 0.6919
# Epoch 32/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0197 - tversky_coefficient: 0.8365 - categorical_crossentropy: 0.1949 - iou_coefficient: 0.7190 - val_loss: 0.0669 - val_tversky_coefficient: 0.8190 - val_categorical_crossentropy: 0.2628 - val_iou_coefficient: 0.6944
# Epoch 33/100
# 17/17 [==============================] - 43s 2s/step - loss: 0.0192 - tversky_coefficient: 0.8362 - categorical_crossentropy: 0.1948 - iou_coefficient: 0.7185 - val_loss: 0.0539 - val_tversky_coefficient: 0.8472 - val_categorical_crossentropy: 0.2213 - val_iou_coefficient: 0.7360
# Epoch 34/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0188 - tversky_coefficient: 0.8403 - categorical_crossentropy: 0.1899 - iou_coefficient: 0.7247 - val_loss: 0.0375 - val_tversky_coefficient: 0.8387 - val_categorical_crossentropy: 0.2149 - val_iou_coefficient: 0.7230
# Epoch 35/100
# 17/17 [==============================] - 43s 2s/step - loss: 0.0184 - tversky_coefficient: 0.8401 - categorical_crossentropy: 0.1896 - iou_coefficient: 0.7243 - val_loss: 0.0224 - val_tversky_coefficient: 0.8645 - val_categorical_crossentropy: 0.1704 - val_iou_coefficient: 0.7618
# Epoch 36/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0192 - tversky_coefficient: 0.8455 - categorical_crossentropy: 0.1845 - iou_coefficient: 0.7324 - val_loss: 0.0264 - val_tversky_coefficient: 0.8458 - val_categorical_crossentropy: 0.1945 - val_iou_coefficient: 0.7334
# Epoch 37/100
# 17/17 [==============================] - 43s 2s/step - loss: 0.0186 - tversky_coefficient: 0.8461 - categorical_crossentropy: 0.1833 - iou_coefficient: 0.7333 - val_loss: 0.0247 - val_tversky_coefficient: 0.8572 - val_categorical_crossentropy: 0.1808 - val_iou_coefficient: 0.7507
# Epoch 38/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0177 - tversky_coefficient: 0.8472 - categorical_crossentropy: 0.1812 - iou_coefficient: 0.7350 - val_loss: 0.0214 - val_tversky_coefficient: 0.8626 - val_categorical_crossentropy: 0.1714 - val_iou_coefficient: 0.7588
# Epoch 39/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0181 - tversky_coefficient: 0.8517 - categorical_crossentropy: 0.1766 - iou_coefficient: 0.7418 - val_loss: 0.0186 - val_tversky_coefficient: 0.8705 - val_categorical_crossentropy: 0.1605 - val_iou_coefficient: 0.7713
# Epoch 40/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0177 - tversky_coefficient: 0.8507 - categorical_crossentropy: 0.1775 - iou_coefficient: 0.7403 - val_loss: 0.0185 - val_tversky_coefficient: 0.8683 - val_categorical_crossentropy: 0.1626 - val_iou_coefficient: 0.7677
# Epoch 41/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0176 - tversky_coefficient: 0.8531 - categorical_crossentropy: 0.1748 - iou_coefficient: 0.7438 - val_loss: 0.0197 - val_tversky_coefficient: 0.8684 - val_categorical_crossentropy: 0.1633 - val_iou_coefficient: 0.7678
# Epoch 42/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0178 - tversky_coefficient: 0.8531 - categorical_crossentropy: 0.1748 - iou_coefficient: 0.7439 - val_loss: 0.0179 - val_tversky_coefficient: 0.8787 - val_categorical_crossentropy: 0.1508 - val_iou_coefficient: 0.7840
# Epoch 43/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0174 - tversky_coefficient: 0.8552 - categorical_crossentropy: 0.1722 - iou_coefficient: 0.7471 - val_loss: 0.0172 - val_tversky_coefficient: 0.8837 - val_categorical_crossentropy: 0.1449 - val_iou_coefficient: 0.7921
# Epoch 44/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0170 - tversky_coefficient: 0.8580 - categorical_crossentropy: 0.1687 - iou_coefficient: 0.7513 - val_loss: 0.0178 - val_tversky_coefficient: 0.8793 - val_categorical_crossentropy: 0.1490 - val_iou_coefficient: 0.7851
# Epoch 45/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0170 - tversky_coefficient: 0.8587 - categorical_crossentropy: 0.1678 - iou_coefficient: 0.7525 - val_loss: 0.0167 - val_tversky_coefficient: 0.8798 - val_categorical_crossentropy: 0.1486 - val_iou_coefficient: 0.7860
# Epoch 46/100
# 17/17 [==============================] - 43s 2s/step - loss: 0.0170 - tversky_coefficient: 0.8584 - categorical_crossentropy: 0.1684 - iou_coefficient: 0.7520 - val_loss: 0.0166 - val_tversky_coefficient: 0.8818 - val_categorical_crossentropy: 0.1459 - val_iou_coefficient: 0.7890
# Epoch 47/100
# 17/17 [==============================] - 42s 3s/step - loss: 0.0170 - tversky_coefficient: 0.8617 - categorical_crossentropy: 0.1646 - iou_coefficient: 0.7571 - val_loss: 0.0183 - val_tversky_coefficient: 0.8791 - val_categorical_crossentropy: 0.1500 - val_iou_coefficient: 0.7846
# Epoch 48/100
# 17/17 [==============================] - 44s 3s/step - loss: 0.0171 - tversky_coefficient: 0.8597 - categorical_crossentropy: 0.1671 - iou_coefficient: 0.7540 - val_loss: 0.0173 - val_tversky_coefficient: 0.8910 - val_categorical_crossentropy: 0.1363 - val_iou_coefficient: 0.8038
# Epoch 49/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0163 - tversky_coefficient: 0.8649 - categorical_crossentropy: 0.1605 - iou_coefficient: 0.7621 - val_loss: 0.0163 - val_tversky_coefficient: 0.8871 - val_categorical_crossentropy: 0.1401 - val_iou_coefficient: 0.7975
# Epoch 50/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0177 - tversky_coefficient: 0.8620 - categorical_crossentropy: 0.1651 - iou_coefficient: 0.7575 - val_loss: 0.0176 - val_tversky_coefficient: 0.8842 - val_categorical_crossentropy: 0.1443 - val_iou_coefficient: 0.7929
# Epoch 51/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0169 - tversky_coefficient: 0.8626 - categorical_crossentropy: 0.1637 - iou_coefficient: 0.7585 - val_loss: 0.0169 - val_tversky_coefficient: 0.8830 - val_categorical_crossentropy: 0.1446 - val_iou_coefficient: 0.7909
# Epoch 52/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0167 - tversky_coefficient: 0.8647 - categorical_crossentropy: 0.1612 - iou_coefficient: 0.7617 - val_loss: 0.0154 - val_tversky_coefficient: 0.8911 - val_categorical_crossentropy: 0.1355 - val_iou_coefficient: 0.8041
# Epoch 53/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0170 - tversky_coefficient: 0.8648 - categorical_crossentropy: 0.1615 - iou_coefficient: 0.7619 - val_loss: 0.0152 - val_tversky_coefficient: 0.8902 - val_categorical_crossentropy: 0.1361 - val_iou_coefficient: 0.8027
# Epoch 54/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0163 - tversky_coefficient: 0.8655 - categorical_crossentropy: 0.1598 - iou_coefficient: 0.7630 - val_loss: 0.0148 - val_tversky_coefficient: 0.8949 - val_categorical_crossentropy: 0.1310 - val_iou_coefficient: 0.8103
# Epoch 55/100
# 17/17 [==============================] - 44s 3s/step - loss: 0.0169 - tversky_coefficient: 0.8680 - categorical_crossentropy: 0.1577 - iou_coefficient: 0.7669 - val_loss: 0.0149 - val_tversky_coefficient: 0.8939 - val_categorical_crossentropy: 0.1322 - val_iou_coefficient: 0.8088
# Epoch 56/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0159 - tversky_coefficient: 0.8709 - categorical_crossentropy: 0.1536 - iou_coefficient: 0.7713 - val_loss: 0.0156 - val_tversky_coefficient: 0.8931 - val_categorical_crossentropy: 0.1336 - val_iou_coefficient: 0.8073
# Epoch 57/100
# 17/17 [==============================] - 43s 3s/step - loss: 0.0162 - tversky_coefficient: 0.8673 - categorical_crossentropy: 0.1580 - iou_coefficient: 0.7657 - val_loss: 0.0154 - val_tversky_coefficient: 0.8924 - val_categorical_crossentropy: 0.1334 - val_iou_coefficient: 0.8062
# Epoch 58/100
# 17/17 [==============================] - 45s 3s/step - loss: 0.0164 - tversky_coefficient: 0.8691 - categorical_crossentropy: 0.1561 - iou_coefficient: 0.7686 - val_loss: 0.0151 - val_tversky_coefficient: 0.8910 - val_categorical_crossentropy: 0.1348 - val_iou_coefficient: 0.8038
# Epoch 59/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0159 - tversky_coefficient: 0.8693 - categorical_crossentropy: 0.1556 - iou_coefficient: 0.7688 - val_loss: 0.0150 - val_tversky_coefficient: 0.8956 - val_categorical_crossentropy: 0.1297 - val_iou_coefficient: 0.8113
# Epoch 60/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0159 - tversky_coefficient: 0.8723 - categorical_crossentropy: 0.1521 - iou_coefficient: 0.7736 - val_loss: 0.0153 - val_tversky_coefficient: 0.8939 - val_categorical_crossentropy: 0.1311 - val_iou_coefficient: 0.8086
# Epoch 61/100
# 17/17 [==============================] - 43s 3s/step - loss: 0.0161 - tversky_coefficient: 0.8746 - categorical_crossentropy: 0.1498 - iou_coefficient: 0.7772 - val_loss: 0.0147 - val_tversky_coefficient: 0.8968 - val_categorical_crossentropy: 0.1285 - val_iou_coefficient: 0.8135
# Epoch 62/100
# 17/17 [==============================] - 44s 3s/step - loss: 0.0164 - tversky_coefficient: 0.8703 - categorical_crossentropy: 0.1550 - iou_coefficient: 0.7705 - val_loss: 0.0164 - val_tversky_coefficient: 0.8966 - val_categorical_crossentropy: 0.1309 - val_iou_coefficient: 0.8131
# Epoch 63/100
# 17/17 [==============================] - 43s 2s/step - loss: 0.0168 - tversky_coefficient: 0.8705 - categorical_crossentropy: 0.1549 - iou_coefficient: 0.7708 - val_loss: 0.0152 - val_tversky_coefficient: 0.8879 - val_categorical_crossentropy: 0.1387 - val_iou_coefficient: 0.7989
# Epoch 64/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0162 - tversky_coefficient: 0.8707 - categorical_crossentropy: 0.1543 - iou_coefficient: 0.7711 - val_loss: 0.0148 - val_tversky_coefficient: 0.8973 - val_categorical_crossentropy: 0.1281 - val_iou_coefficient: 0.8142
# Epoch 65/100
# 17/17 [==============================] - 43s 3s/step - loss: 0.0159 - tversky_coefficient: 0.8727 - categorical_crossentropy: 0.1518 - iou_coefficient: 0.7743 - val_loss: 0.0166 - val_tversky_coefficient: 0.8928 - val_categorical_crossentropy: 0.1343 - val_iou_coefficient: 0.8069
# Epoch 66/100
# 17/17 [==============================] - 43s 2s/step - loss: 0.0165 - tversky_coefficient: 0.8732 - categorical_crossentropy: 0.1519 - iou_coefficient: 0.7749 - val_loss: 0.0153 - val_tversky_coefficient: 0.8921 - val_categorical_crossentropy: 0.1344 - val_iou_coefficient: 0.8056
# Epoch 67/100
# 17/17 [==============================] - 46s 3s/step - loss: 0.0159 - tversky_coefficient: 0.8741 - categorical_crossentropy: 0.1502 - iou_coefficient: 0.7764 - val_loss: 0.0151 - val_tversky_coefficient: 0.8982 - val_categorical_crossentropy: 0.1281 - val_iou_coefficient: 0.8157
# Epoch 68/100
# 17/17 [==============================] - 45s 3s/step - loss: 0.0160 - tversky_coefficient: 0.8733 - categorical_crossentropy: 0.1513 - iou_coefficient: 0.7752 - val_loss: 0.0149 - val_tversky_coefficient: 0.8958 - val_categorical_crossentropy: 0.1294 - val_iou_coefficient: 0.8117
# Epoch 69/100
# 17/17 [==============================] - 42s 2s/step - loss: 0.0154 - tversky_coefficient: 0.8758 - categorical_crossentropy: 0.1481 - iou_coefficient: 0.7791 - val_loss: 0.0148 - val_tversky_coefficient: 0.8970 - val_categorical_crossentropy: 0.1278 - val_iou_coefficient: 0.8136
# Epoch 70/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0156 - tversky_coefficient: 0.8761 - categorical_crossentropy: 0.1477 - iou_coefficient: 0.7796 - val_loss: 0.0152 - val_tversky_coefficient: 0.8981 - val_categorical_crossentropy: 0.1272 - val_iou_coefficient: 0.8155
# Epoch 71/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0162 - tversky_coefficient: 0.8744 - categorical_crossentropy: 0.1505 - iou_coefficient: 0.7770 - val_loss: 0.0152 - val_tversky_coefficient: 0.8943 - val_categorical_crossentropy: 0.1326 - val_iou_coefficient: 0.8093
# Epoch 72/100
# 17/17 [==============================] - 43s 2s/step - loss: 0.0158 - tversky_coefficient: 0.8770 - categorical_crossentropy: 0.1471 - iou_coefficient: 0.7811 - val_loss: 0.0145 - val_tversky_coefficient: 0.8946 - val_categorical_crossentropy: 0.1313 - val_iou_coefficient: 0.8098
# Epoch 73/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0157 - tversky_coefficient: 0.8755 - categorical_crossentropy: 0.1487 - iou_coefficient: 0.7787 - val_loss: 0.0145 - val_tversky_coefficient: 0.8972 - val_categorical_crossentropy: 0.1288 - val_iou_coefficient: 0.8141
# Epoch 74/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0159 - tversky_coefficient: 0.8770 - categorical_crossentropy: 0.1472 - iou_coefficient: 0.7811 - val_loss: 0.0162 - val_tversky_coefficient: 0.8922 - val_categorical_crossentropy: 0.1346 - val_iou_coefficient: 0.8058
# Epoch 75/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0154 - tversky_coefficient: 0.8799 - categorical_crossentropy: 0.1435 - iou_coefficient: 0.7856 - val_loss: 0.0145 - val_tversky_coefficient: 0.9028 - val_categorical_crossentropy: 0.1221 - val_iou_coefficient: 0.8234
# Epoch 76/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0153 - tversky_coefficient: 0.8785 - categorical_crossentropy: 0.1450 - iou_coefficient: 0.7833 - val_loss: 0.0150 - val_tversky_coefficient: 0.8982 - val_categorical_crossentropy: 0.1268 - val_iou_coefficient: 0.8156
# Epoch 77/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0159 - tversky_coefficient: 0.8775 - categorical_crossentropy: 0.1467 - iou_coefficient: 0.7817 - val_loss: 0.0151 - val_tversky_coefficient: 0.9095 - val_categorical_crossentropy: 0.1150 - val_iou_coefficient: 0.8345
# Epoch 78/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0156 - tversky_coefficient: 0.8795 - categorical_crossentropy: 0.1441 - iou_coefficient: 0.7850 - val_loss: 0.0152 - val_tversky_coefficient: 0.9025 - val_categorical_crossentropy: 0.1235 - val_iou_coefficient: 0.8230
# Epoch 79/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0158 - tversky_coefficient: 0.8783 - categorical_crossentropy: 0.1456 - iou_coefficient: 0.7830 - val_loss: 0.0151 - val_tversky_coefficient: 0.9084 - val_categorical_crossentropy: 0.1161 - val_iou_coefficient: 0.8326
# Epoch 80/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0154 - tversky_coefficient: 0.8783 - categorical_crossentropy: 0.1453 - iou_coefficient: 0.7831 - val_loss: 0.0141 - val_tversky_coefficient: 0.9069 - val_categorical_crossentropy: 0.1170 - val_iou_coefficient: 0.8302
# Epoch 81/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0152 - tversky_coefficient: 0.8811 - categorical_crossentropy: 0.1420 - iou_coefficient: 0.7875 - val_loss: 0.0144 - val_tversky_coefficient: 0.9053 - val_categorical_crossentropy: 0.1188 - val_iou_coefficient: 0.8274
# Epoch 82/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0151 - tversky_coefficient: 0.8810 - categorical_crossentropy: 0.1419 - iou_coefficient: 0.7874 - val_loss: 0.0141 - val_tversky_coefficient: 0.8974 - val_categorical_crossentropy: 0.1283 - val_iou_coefficient: 0.8145
# Epoch 83/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0150 - tversky_coefficient: 0.8826 - categorical_crossentropy: 0.1403 - iou_coefficient: 0.7899 - val_loss: 0.0150 - val_tversky_coefficient: 0.9028 - val_categorical_crossentropy: 0.1219 - val_iou_coefficient: 0.8232
# Epoch 84/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0155 - tversky_coefficient: 0.8809 - categorical_crossentropy: 0.1426 - iou_coefficient: 0.7873 - val_loss: 0.0141 - val_tversky_coefficient: 0.9007 - val_categorical_crossentropy: 0.1251 - val_iou_coefficient: 0.8199
# Epoch 85/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0149 - tversky_coefficient: 0.8809 - categorical_crossentropy: 0.1421 - iou_coefficient: 0.7872 - val_loss: 0.0147 - val_tversky_coefficient: 0.9043 - val_categorical_crossentropy: 0.1194 - val_iou_coefficient: 0.8257
# Epoch 86/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0154 - tversky_coefficient: 0.8826 - categorical_crossentropy: 0.1407 - iou_coefficient: 0.7899 - val_loss: 0.0145 - val_tversky_coefficient: 0.9011 - val_categorical_crossentropy: 0.1247 - val_iou_coefficient: 0.8206
# Epoch 87/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0151 - tversky_coefficient: 0.8820 - categorical_crossentropy: 0.1411 - iou_coefficient: 0.7889 - val_loss: 0.0145 - val_tversky_coefficient: 0.9078 - val_categorical_crossentropy: 0.1165 - val_iou_coefficient: 0.8317
# Epoch 88/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0149 - tversky_coefficient: 0.8837 - categorical_crossentropy: 0.1391 - iou_coefficient: 0.7916 - val_loss: 0.0142 - val_tversky_coefficient: 0.9034 - val_categorical_crossentropy: 0.1204 - val_iou_coefficient: 0.8243
# Epoch 89/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0151 - tversky_coefficient: 0.8837 - categorical_crossentropy: 0.1392 - iou_coefficient: 0.7917 - val_loss: 0.0143 - val_tversky_coefficient: 0.9004 - val_categorical_crossentropy: 0.1236 - val_iou_coefficient: 0.8192
# Epoch 90/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0151 - tversky_coefficient: 0.8850 - categorical_crossentropy: 0.1377 - iou_coefficient: 0.7938 - val_loss: 0.0152 - val_tversky_coefficient: 0.8955 - val_categorical_crossentropy: 0.1312 - val_iou_coefficient: 0.8113
# Epoch 91/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0150 - tversky_coefficient: 0.8820 - categorical_crossentropy: 0.1412 - iou_coefficient: 0.7889 - val_loss: 0.0141 - val_tversky_coefficient: 0.9020 - val_categorical_crossentropy: 0.1217 - val_iou_coefficient: 0.8219
# Epoch 92/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0150 - tversky_coefficient: 0.8835 - categorical_crossentropy: 0.1394 - iou_coefficient: 0.7914 - val_loss: 0.0145 - val_tversky_coefficient: 0.9045 - val_categorical_crossentropy: 0.1195 - val_iou_coefficient: 0.8260
# Epoch 93/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0151 - tversky_coefficient: 0.8832 - categorical_crossentropy: 0.1398 - iou_coefficient: 0.7909 - val_loss: 0.0141 - val_tversky_coefficient: 0.9022 - val_categorical_crossentropy: 0.1219 - val_iou_coefficient: 0.8223
# Epoch 94/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0147 - tversky_coefficient: 0.8851 - categorical_crossentropy: 0.1374 - iou_coefficient: 0.7939 - val_loss: 0.0141 - val_tversky_coefficient: 0.9057 - val_categorical_crossentropy: 0.1176 - val_iou_coefficient: 0.8280
# Epoch 95/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0146 - tversky_coefficient: 0.8875 - categorical_crossentropy: 0.1346 - iou_coefficient: 0.7979 - val_loss: 0.0140 - val_tversky_coefficient: 0.9037 - val_categorical_crossentropy: 0.1205 - val_iou_coefficient: 0.8248
# Epoch 96/100
# 17/17 [==============================] - 41s 2s/step - loss: 0.0148 - tversky_coefficient: 0.8854 - categorical_crossentropy: 0.1371 - iou_coefficient: 0.7945 - val_loss: 0.0145 - val_tversky_coefficient: 0.9122 - val_categorical_crossentropy: 0.1112 - val_iou_coefficient: 0.8391
# Epoch 97/100
# 17/17 [==============================] - 39s 2s/step - loss: 0.0145 - tversky_coefficient: 0.8882 - categorical_crossentropy: 0.1338 - iou_coefficient: 0.7989 - val_loss: 0.0147 - val_tversky_coefficient: 0.9029 - val_categorical_crossentropy: 0.1216 - val_iou_coefficient: 0.8235
# Epoch 98/100
# 17/17 [==============================] - 38s 2s/step - loss: 0.0147 - tversky_coefficient: 0.8861 - categorical_crossentropy: 0.1363 - iou_coefficient: 0.7955 - val_loss: 0.0150 - val_tversky_coefficient: 0.9079 - val_categorical_crossentropy: 0.1163 - val_iou_coefficient: 0.8318
# Epoch 99/100
# 17/17 [==============================] - 40s 2s/step - loss: 0.0147 - tversky_coefficient: 0.8882 - categorical_crossentropy: 0.1338 - iou_coefficient: 0.7990 - val_loss: 0.0143 - val_tversky_coefficient: 0.9110 - val_categorical_crossentropy: 0.1129 - val_iou_coefficient: 0.8369
# Epoch 100/100
# 17/17 [==============================] - 37s 2s/step - loss: 0.0145 - tversky_coefficient: 0.8839 - categorical_crossentropy: 0.1385 - iou_coefficient: 0.7920 - val_loss: 0.0140 - val_tversky_coefficient: 0.9120 - val_categorical_crossentropy: 0.1114 - val_iou_coefficient: 0.8387
# 536 images detected!
# Set 'steps_per_epoch' to: 67
# 134 images detected!
# Set 'steps_per_epoch' to: 17
# 134 images detected!
# Set 'steps_per_epoch' to: 17
# Epoch 1/100
# 67/67 [==============================] - 47s 659ms/step - loss: 0.1411 - categorical_crossentropy: 0.6694 - tversky_coefficient: 0.5228 - iou_coefficient: 0.3540 - val_loss: 0.1161 - val_categorical_crossentropy: 0.6414 - val_tversky_coefficient: 0.5273 - val_iou_coefficient: 0.3581
# Epoch 2/100
# 67/67 [==============================] - 44s 664ms/step - loss: 0.0947 - categorical_crossentropy: 0.5657 - tversky_coefficient: 0.5750 - iou_coefficient: 0.4038 - val_loss: 0.0980 - val_categorical_crossentropy: 0.5879 - val_tversky_coefficient: 0.5589 - val_iou_coefficient: 0.3878
# Epoch 3/100
# 67/67 [==============================] - 45s 662ms/step - loss: 0.0670 - categorical_crossentropy: 0.4556 - tversky_coefficient: 0.6469 - iou_coefficient: 0.4785 - val_loss: 0.0875 - val_categorical_crossentropy: 0.5396 - val_tversky_coefficient: 0.5912 - val_iou_coefficient: 0.4198
# Epoch 4/100
# 67/67 [==============================] - 45s 662ms/step - loss: 0.0475 - categorical_crossentropy: 0.3710 - tversky_coefficient: 0.7042 - iou_coefficient: 0.5438 - val_loss: 0.0840 - val_categorical_crossentropy: 0.4930 - val_tversky_coefficient: 0.6270 - val_iou_coefficient: 0.4569
# Epoch 5/100
# 67/67 [==============================] - 46s 682ms/step - loss: 0.0396 - categorical_crossentropy: 0.3176 - tversky_coefficient: 0.7442 - iou_coefficient: 0.5928 - val_loss: 0.0833 - val_categorical_crossentropy: 0.4578 - val_tversky_coefficient: 0.6558 - val_iou_coefficient: 0.4883
# Epoch 6/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.0348 - categorical_crossentropy: 0.2877 - tversky_coefficient: 0.7666 - iou_coefficient: 0.6216 - val_loss: 0.0860 - val_categorical_crossentropy: 0.4105 - val_tversky_coefficient: 0.6975 - val_iou_coefficient: 0.5363
# Epoch 7/100
# 67/67 [==============================] - 46s 680ms/step - loss: 0.0359 - categorical_crossentropy: 0.2737 - tversky_coefficient: 0.7796 - iou_coefficient: 0.6391 - val_loss: 0.0620 - val_categorical_crossentropy: 0.3917 - val_tversky_coefficient: 0.6969 - val_iou_coefficient: 0.5353
# Epoch 8/100
# 67/67 [==============================] - 45s 675ms/step - loss: 0.0315 - categorical_crossentropy: 0.2639 - tversky_coefficient: 0.7850 - iou_coefficient: 0.6462 - val_loss: 0.0868 - val_categorical_crossentropy: 0.3306 - val_tversky_coefficient: 0.7682 - val_iou_coefficient: 0.6253
# Epoch 9/100
# 67/67 [==============================] - 45s 672ms/step - loss: 0.0308 - categorical_crossentropy: 0.2511 - tversky_coefficient: 0.7958 - iou_coefficient: 0.6610 - val_loss: 0.1019 - val_categorical_crossentropy: 0.3049 - val_tversky_coefficient: 0.8036 - val_iou_coefficient: 0.6738
# Epoch 10/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.0295 - categorical_crossentropy: 0.2413 - tversky_coefficient: 0.8035 - iou_coefficient: 0.6717 - val_loss: 0.0469 - val_categorical_crossentropy: 0.3811 - val_tversky_coefficient: 0.6958 - val_iou_coefficient: 0.5344
# Epoch 11/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.0288 - categorical_crossentropy: 0.2354 - tversky_coefficient: 0.8083 - iou_coefficient: 0.6785 - val_loss: 0.0763 - val_categorical_crossentropy: 0.2491 - val_tversky_coefficient: 0.8341 - val_iou_coefficient: 0.7175
# Epoch 12/100
# 67/67 [==============================] - 42s 617ms/step - loss: 0.0303 - categorical_crossentropy: 0.2366 - tversky_coefficient: 0.8082 - iou_coefficient: 0.6783 - val_loss: 0.0751 - val_categorical_crossentropy: 0.2546 - val_tversky_coefficient: 0.8277 - val_iou_coefficient: 0.7077
# Epoch 13/100
# 67/67 [==============================] - 43s 635ms/step - loss: 0.0264 - categorical_crossentropy: 0.2220 - tversky_coefficient: 0.8182 - iou_coefficient: 0.6924 - val_loss: 0.3087 - val_categorical_crossentropy: 0.8456 - val_tversky_coefficient: 0.4872 - val_iou_coefficient: 0.3254
# Epoch 14/100
# 67/67 [==============================] - 45s 663ms/step - loss: 0.0278 - categorical_crossentropy: 0.2255 - tversky_coefficient: 0.8164 - iou_coefficient: 0.6899 - val_loss: 0.0288 - val_categorical_crossentropy: 0.2214 - val_tversky_coefficient: 0.8212 - val_iou_coefficient: 0.6976
# Epoch 15/100
# 67/67 [==============================] - 43s 635ms/step - loss: 0.0291 - categorical_crossentropy: 0.2260 - tversky_coefficient: 0.8170 - iou_coefficient: 0.6910 - val_loss: 0.2662 - val_categorical_crossentropy: 0.7674 - val_tversky_coefficient: 0.5245 - val_iou_coefficient: 0.3590
# Epoch 16/100
# 67/67 [==============================] - 45s 664ms/step - loss: 0.0271 - categorical_crossentropy: 0.2200 - tversky_coefficient: 0.8207 - iou_coefficient: 0.6960 - val_loss: 0.0818 - val_categorical_crossentropy: 0.4410 - val_tversky_coefficient: 0.6704 - val_iou_coefficient: 0.5061
# Epoch 17/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.0263 - categorical_crossentropy: 0.2159 - tversky_coefficient: 0.8238 - iou_coefficient: 0.7006 - val_loss: 0.0346 - val_categorical_crossentropy: 0.2216 - val_tversky_coefficient: 0.8274 - val_iou_coefficient: 0.7083
# Epoch 18/100
# 67/67 [==============================] - 46s 668ms/step - loss: 0.0265 - categorical_crossentropy: 0.2156 - tversky_coefficient: 0.8241 - iou_coefficient: 0.7011 - val_loss: 0.0304 - val_categorical_crossentropy: 0.1843 - val_tversky_coefficient: 0.8564 - val_iou_coefficient: 0.7504
# Epoch 19/100
# 67/67 [==============================] - 46s 680ms/step - loss: 0.0243 - categorical_crossentropy: 0.2063 - tversky_coefficient: 0.8307 - iou_coefficient: 0.7107 - val_loss: 0.0271 - val_categorical_crossentropy: 0.1977 - val_tversky_coefficient: 0.8409 - val_iou_coefficient: 0.7264
# Epoch 20/100
# 67/67 [==============================] - 45s 660ms/step - loss: 0.0238 - categorical_crossentropy: 0.2002 - tversky_coefficient: 0.8357 - iou_coefficient: 0.7180 - val_loss: 0.0644 - val_categorical_crossentropy: 0.3430 - val_tversky_coefficient: 0.7424 - val_iou_coefficient: 0.5928
# Epoch 21/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.0245 - categorical_crossentropy: 0.1985 - tversky_coefficient: 0.8378 - iou_coefficient: 0.7211 - val_loss: 0.0759 - val_categorical_crossentropy: 0.3057 - val_tversky_coefficient: 0.7836 - val_iou_coefficient: 0.6457
# Epoch 22/100
# 67/67 [==============================] - 44s 657ms/step - loss: 0.0256 - categorical_crossentropy: 0.2033 - tversky_coefficient: 0.8347 - iou_coefficient: 0.7164 - val_loss: 0.7215 - val_categorical_crossentropy: 1.3012 - val_tversky_coefficient: 0.3930 - val_iou_coefficient: 0.2489
# Epoch 23/100
# 67/67 [==============================] - 45s 677ms/step - loss: 0.0249 - categorical_crossentropy: 0.2047 - tversky_coefficient: 0.8329 - iou_coefficient: 0.7138 - val_loss: 0.1789 - val_categorical_crossentropy: 0.6576 - val_tversky_coefficient: 0.5567 - val_iou_coefficient: 0.3882
# Epoch 24/100
# 67/67 [==============================] - 47s 695ms/step - loss: 0.0238 - categorical_crossentropy: 0.1955 - tversky_coefficient: 0.8401 - iou_coefficient: 0.7245 - val_loss: 0.0284 - val_categorical_crossentropy: 0.2481 - val_tversky_coefficient: 0.7976 - val_iou_coefficient: 0.6648
# Epoch 25/100
# 67/67 [==============================] - 45s 657ms/step - loss: 0.0249 - categorical_crossentropy: 0.2006 - tversky_coefficient: 0.8364 - iou_coefficient: 0.7190 - val_loss: 0.0336 - val_categorical_crossentropy: 0.1908 - val_tversky_coefficient: 0.8533 - val_iou_coefficient: 0.7458
# Epoch 26/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.0239 - categorical_crossentropy: 0.1966 - tversky_coefficient: 0.8392 - iou_coefficient: 0.7231 - val_loss: 0.0779 - val_categorical_crossentropy: 0.2986 - val_tversky_coefficient: 0.7950 - val_iou_coefficient: 0.6649
# Epoch 27/100
# 67/67 [==============================] - 46s 682ms/step - loss: 0.0239 - categorical_crossentropy: 0.1993 - tversky_coefficient: 0.8368 - iou_coefficient: 0.7197 - val_loss: 0.0373 - val_categorical_crossentropy: 0.1966 - val_tversky_coefficient: 0.8503 - val_iou_coefficient: 0.7412
# Epoch 28/100
# 67/67 [==============================] - 46s 679ms/step - loss: 0.0221 - categorical_crossentropy: 0.1860 - tversky_coefficient: 0.8472 - iou_coefficient: 0.7351 - val_loss: 0.0322 - val_categorical_crossentropy: 0.1930 - val_tversky_coefficient: 0.8497 - val_iou_coefficient: 0.7401
# Epoch 29/100
# 67/67 [==============================] - 45s 660ms/step - loss: 0.0223 - categorical_crossentropy: 0.1863 - tversky_coefficient: 0.8473 - iou_coefficient: 0.7352 - val_loss: 0.0616 - val_categorical_crossentropy: 0.2389 - val_tversky_coefficient: 0.8326 - val_iou_coefficient: 0.7153
# Epoch 30/100
# 67/67 [==============================] - 46s 678ms/step - loss: 0.0216 - categorical_crossentropy: 0.1811 - tversky_coefficient: 0.8513 - iou_coefficient: 0.7413 - val_loss: 0.2552 - val_categorical_crossentropy: 0.7682 - val_tversky_coefficient: 0.5157 - val_iou_coefficient: 0.3505
# Epoch 31/100
# 67/67 [==============================] - 45s 672ms/step - loss: 0.0216 - categorical_crossentropy: 0.1812 - tversky_coefficient: 0.8513 - iou_coefficient: 0.7413 - val_loss: 0.2735 - val_categorical_crossentropy: 0.8141 - val_tversky_coefficient: 0.4896 - val_iou_coefficient: 0.3266
# Epoch 32/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.0215 - categorical_crossentropy: 0.1794 - tversky_coefficient: 0.8529 - iou_coefficient: 0.7437 - val_loss: 0.2389 - val_categorical_crossentropy: 0.7185 - val_tversky_coefficient: 0.5463 - val_iou_coefficient: 0.3791
# Epoch 33/100
# 67/67 [==============================] - 45s 667ms/step - loss: 0.0223 - categorical_crossentropy: 0.1827 - tversky_coefficient: 0.8506 - iou_coefficient: 0.7402 - val_loss: 0.0715 - val_categorical_crossentropy: 0.3595 - val_tversky_coefficient: 0.7330 - val_iou_coefficient: 0.5809
# Epoch 34/100
# 67/67 [==============================] - 45s 667ms/step - loss: 0.0212 - categorical_crossentropy: 0.1758 - tversky_coefficient: 0.8559 - iou_coefficient: 0.7483 - val_loss: 0.0225 - val_categorical_crossentropy: 0.1920 - val_tversky_coefficient: 0.8431 - val_iou_coefficient: 0.7302
# Epoch 35/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.0209 - categorical_crossentropy: 0.1735 - tversky_coefficient: 0.8577 - iou_coefficient: 0.7511 - val_loss: 0.0221 - val_categorical_crossentropy: 0.1715 - val_tversky_coefficient: 0.8612 - val_iou_coefficient: 0.7577
# Epoch 36/100
# 67/67 [==============================] - 44s 654ms/step - loss: 0.0223 - categorical_crossentropy: 0.1771 - tversky_coefficient: 0.8557 - iou_coefficient: 0.7480 - val_loss: 0.0293 - val_categorical_crossentropy: 0.2241 - val_tversky_coefficient: 0.8198 - val_iou_coefficient: 0.6959
# Epoch 37/100
# 67/67 [==============================] - 46s 674ms/step - loss: 0.0219 - categorical_crossentropy: 0.1785 - tversky_coefficient: 0.8542 - iou_coefficient: 0.7458 - val_loss: 0.0327 - val_categorical_crossentropy: 0.2626 - val_tversky_coefficient: 0.7882 - val_iou_coefficient: 0.6518
# Epoch 38/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.0213 - categorical_crossentropy: 0.1763 - tversky_coefficient: 0.8556 - iou_coefficient: 0.7479 - val_loss: 0.0386 - val_categorical_crossentropy: 0.2672 - val_tversky_coefficient: 0.7894 - val_iou_coefficient: 0.6539
# Epoch 39/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.0210 - categorical_crossentropy: 0.1725 - tversky_coefficient: 0.8588 - iou_coefficient: 0.7528 - val_loss: 0.0240 - val_categorical_crossentropy: 0.1883 - val_tversky_coefficient: 0.8470 - val_iou_coefficient: 0.7358
# Epoch 40/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.0199 - categorical_crossentropy: 0.1687 - tversky_coefficient: 0.8613 - iou_coefficient: 0.7565 - val_loss: 0.1118 - val_categorical_crossentropy: 0.5171 - val_tversky_coefficient: 0.6285 - val_iou_coefficient: 0.4600
# Epoch 41/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.0209 - categorical_crossentropy: 0.1708 - tversky_coefficient: 0.8603 - iou_coefficient: 0.7551 - val_loss: 0.0568 - val_categorical_crossentropy: 0.2460 - val_tversky_coefficient: 0.8208 - val_iou_coefficient: 0.6973
# Epoch 42/100
# 67/67 [==============================] - 46s 679ms/step - loss: 0.0200 - categorical_crossentropy: 0.1665 - tversky_coefficient: 0.8633 - iou_coefficient: 0.7598 - val_loss: 0.0475 - val_categorical_crossentropy: 0.2765 - val_tversky_coefficient: 0.7871 - val_iou_coefficient: 0.6503
# Epoch 43/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.0195 - categorical_crossentropy: 0.1647 - tversky_coefficient: 0.8646 - iou_coefficient: 0.7618 - val_loss: 0.0223 - val_categorical_crossentropy: 0.1757 - val_tversky_coefficient: 0.8571 - val_iou_coefficient: 0.7510
# Epoch 44/100
# 67/67 [==============================] - 46s 688ms/step - loss: 0.0193 - categorical_crossentropy: 0.1623 - tversky_coefficient: 0.8666 - iou_coefficient: 0.7649 - val_loss: 0.0269 - val_categorical_crossentropy: 0.2309 - val_tversky_coefficient: 0.8118 - val_iou_coefficient: 0.6846
# Epoch 45/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.0192 - categorical_crossentropy: 0.1616 - tversky_coefficient: 0.8671 - iou_coefficient: 0.7657 - val_loss: 0.0263 - val_categorical_crossentropy: 0.1606 - val_tversky_coefficient: 0.8743 - val_iou_coefficient: 0.7782
# Epoch 46/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.0192 - categorical_crossentropy: 0.1603 - tversky_coefficient: 0.8683 - iou_coefficient: 0.7675 - val_loss: 0.0528 - val_categorical_crossentropy: 0.2125 - val_tversky_coefficient: 0.8486 - val_iou_coefficient: 0.7385
# Epoch 47/100
# 67/67 [==============================] - 46s 679ms/step - loss: 0.0242 - categorical_crossentropy: 0.1719 - tversky_coefficient: 0.8621 - iou_coefficient: 0.7581 - val_loss: 0.0501 - val_categorical_crossentropy: 0.3447 - val_tversky_coefficient: 0.7301 - val_iou_coefficient: 0.5754
# Epoch 48/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.0270 - categorical_crossentropy: 0.2083 - tversky_coefficient: 0.8317 - iou_coefficient: 0.7122 - val_loss: 0.0489 - val_categorical_crossentropy: 0.2341 - val_tversky_coefficient: 0.8277 - val_iou_coefficient: 0.7089
# Epoch 49/100
# 67/67 [==============================] - 46s 678ms/step - loss: 0.0217 - categorical_crossentropy: 0.1817 - tversky_coefficient: 0.8508 - iou_coefficient: 0.7406 - val_loss: 0.0268 - val_categorical_crossentropy: 0.1803 - val_tversky_coefficient: 0.8565 - val_iou_coefficient: 0.7504
# Epoch 50/100
# 67/67 [==============================] - 45s 660ms/step - loss: 0.0208 - categorical_crossentropy: 0.1785 - tversky_coefficient: 0.8530 - iou_coefficient: 0.7439 - val_loss: 0.0240 - val_categorical_crossentropy: 0.1875 - val_tversky_coefficient: 0.8475 - val_iou_coefficient: 0.7361
# Epoch 51/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.0202 - categorical_crossentropy: 0.1716 - tversky_coefficient: 0.8587 - iou_coefficient: 0.7526 - val_loss: 0.0639 - val_categorical_crossentropy: 0.3419 - val_tversky_coefficient: 0.7431 - val_iou_coefficient: 0.5937
# Epoch 52/100
# 67/67 [==============================] - 45s 674ms/step - loss: 0.0194 - categorical_crossentropy: 0.1683 - tversky_coefficient: 0.8611 - iou_coefficient: 0.7563 - val_loss: 0.0846 - val_categorical_crossentropy: 0.3652 - val_tversky_coefficient: 0.7380 - val_iou_coefficient: 0.5883
# Epoch 53/100
# 67/67 [==============================] - 46s 682ms/step - loss: 0.0195 - categorical_crossentropy: 0.1641 - tversky_coefficient: 0.8650 - iou_coefficient: 0.7624 - val_loss: 0.0699 - val_categorical_crossentropy: 0.3492 - val_tversky_coefficient: 0.7410 - val_iou_coefficient: 0.5913
# Epoch 54/100
# 67/67 [==============================] - 44s 649ms/step - loss: 0.0194 - categorical_crossentropy: 0.1656 - tversky_coefficient: 0.8635 - iou_coefficient: 0.7600 - val_loss: 0.0224 - val_categorical_crossentropy: 0.2050 - val_tversky_coefficient: 0.8299 - val_iou_coefficient: 0.7100
# Epoch 55/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.0192 - categorical_crossentropy: 0.1625 - tversky_coefficient: 0.8663 - iou_coefficient: 0.7643 - val_loss: 0.0526 - val_categorical_crossentropy: 0.3895 - val_tversky_coefficient: 0.6935 - val_iou_coefficient: 0.5316
# Epoch 56/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.0197 - categorical_crossentropy: 0.1643 - tversky_coefficient: 0.8649 - iou_coefficient: 0.7622 - val_loss: 0.0704 - val_categorical_crossentropy: 0.3391 - val_tversky_coefficient: 0.7503 - val_iou_coefficient: 0.6035
# Epoch 57/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.0198 - categorical_crossentropy: 0.1672 - tversky_coefficient: 0.8625 - iou_coefficient: 0.7585 - val_loss: 0.0210 - val_categorical_crossentropy: 0.1492 - val_tversky_coefficient: 0.8804 - val_iou_coefficient: 0.7878
# Epoch 58/100
# 67/67 [==============================] - 45s 664ms/step - loss: 0.0183 - categorical_crossentropy: 0.1591 - tversky_coefficient: 0.8685 - iou_coefficient: 0.7677 - val_loss: 0.1067 - val_categorical_crossentropy: 0.4812 - val_tversky_coefficient: 0.6546 - val_iou_coefficient: 0.4888
# Epoch 59/100
# 67/67 [==============================] - 46s 669ms/step - loss: 0.0184 - categorical_crossentropy: 0.1583 - tversky_coefficient: 0.8693 - iou_coefficient: 0.7691 - val_loss: 0.1127 - val_categorical_crossentropy: 0.5107 - val_tversky_coefficient: 0.6344 - val_iou_coefficient: 0.4668
# Epoch 60/100
# 67/67 [==============================] - 46s 688ms/step - loss: 0.0183 - categorical_crossentropy: 0.1566 - tversky_coefficient: 0.8708 - iou_coefficient: 0.7713 - val_loss: 0.0237 - val_categorical_crossentropy: 0.1892 - val_tversky_coefficient: 0.8459 - val_iou_coefficient: 0.7342
# Epoch 61/100
# 67/67 [==============================] - 44s 646ms/step - loss: 0.0181 - categorical_crossentropy: 0.1552 - tversky_coefficient: 0.8720 - iou_coefficient: 0.7733 - val_loss: 0.0460 - val_categorical_crossentropy: 0.2771 - val_tversky_coefficient: 0.7867 - val_iou_coefficient: 0.6509
# Epoch 62/100
# 67/67 [==============================] - 46s 669ms/step - loss: 0.0183 - categorical_crossentropy: 0.1567 - tversky_coefficient: 0.8708 - iou_coefficient: 0.7714 - val_loss: 0.0202 - val_categorical_crossentropy: 0.1625 - val_tversky_coefficient: 0.8671 - val_iou_coefficient: 0.7667
# Epoch 63/100
# 67/67 [==============================] - 45s 663ms/step - loss: 0.0174 - categorical_crossentropy: 0.1513 - tversky_coefficient: 0.8750 - iou_coefficient: 0.7780 - val_loss: 0.1327 - val_categorical_crossentropy: 0.5450 - val_tversky_coefficient: 0.6189 - val_iou_coefficient: 0.4503
# Epoch 64/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.0184 - categorical_crossentropy: 0.1526 - tversky_coefficient: 0.8747 - iou_coefficient: 0.7775 - val_loss: 0.0444 - val_categorical_crossentropy: 0.2896 - val_tversky_coefficient: 0.7744 - val_iou_coefficient: 0.6341
# Epoch 65/100
# 67/67 [==============================] - 46s 680ms/step - loss: 0.0183 - categorical_crossentropy: 0.1529 - tversky_coefficient: 0.8742 - iou_coefficient: 0.7768 - val_loss: 0.0277 - val_categorical_crossentropy: 0.1797 - val_tversky_coefficient: 0.8594 - val_iou_coefficient: 0.7564
# Epoch 66/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.0183 - categorical_crossentropy: 0.1543 - tversky_coefficient: 0.8730 - iou_coefficient: 0.7748 - val_loss: 0.0343 - val_categorical_crossentropy: 0.1902 - val_tversky_coefficient: 0.8535 - val_iou_coefficient: 0.7460
# Epoch 67/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.0181 - categorical_crossentropy: 0.1539 - tversky_coefficient: 0.8733 - iou_coefficient: 0.7753 - val_loss: 0.0444 - val_categorical_crossentropy: 0.2837 - val_tversky_coefficient: 0.7794 - val_iou_coefficient: 0.6408
# Epoch 68/100
# 67/67 [==============================] - 44s 654ms/step - loss: 0.0175 - categorical_crossentropy: 0.1486 - tversky_coefficient: 0.8776 - iou_coefficient: 0.7821 - val_loss: 0.0620 - val_categorical_crossentropy: 0.3737 - val_tversky_coefficient: 0.7139 - val_iou_coefficient: 0.5567
# Epoch 69/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.0176 - categorical_crossentropy: 0.1491 - tversky_coefficient: 0.8772 - iou_coefficient: 0.7815 - val_loss: 0.0889 - val_categorical_crossentropy: 0.3982 - val_tversky_coefficient: 0.7125 - val_iou_coefficient: 0.5564
# Epoch 70/100
# 67/67 [==============================] - 46s 684ms/step - loss: 0.0172 - categorical_crossentropy: 0.1470 - tversky_coefficient: 0.8788 - iou_coefficient: 0.7841 - val_loss: 0.0216 - val_categorical_crossentropy: 0.1763 - val_tversky_coefficient: 0.8562 - val_iou_coefficient: 0.7501
# Epoch 71/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.0178 - categorical_crossentropy: 0.1483 - tversky_coefficient: 0.8781 - iou_coefficient: 0.7830 - val_loss: 0.0217 - val_categorical_crossentropy: 0.1738 - val_tversky_coefficient: 0.8582 - val_iou_coefficient: 0.7530
# Epoch 72/100
# 67/67 [==============================] - 46s 681ms/step - loss: 0.0177 - categorical_crossentropy: 0.1477 - tversky_coefficient: 0.8786 - iou_coefficient: 0.7837 - val_loss: 0.0233 - val_categorical_crossentropy: 0.2031 - val_tversky_coefficient: 0.8332 - val_iou_coefficient: 0.7153
# Epoch 73/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.0174 - categorical_crossentropy: 0.1467 - tversky_coefficient: 0.8793 - iou_coefficient: 0.7848 - val_loss: 0.0928 - val_categorical_crossentropy: 0.4380 - val_tversky_coefficient: 0.6819 - val_iou_coefficient: 0.5197
# Epoch 74/100
# 67/67 [==============================] - 51s 754ms/step - loss: 0.0178 - categorical_crossentropy: 0.1485 - tversky_coefficient: 0.8780 - iou_coefficient: 0.7827 - val_loss: 0.0444 - val_categorical_crossentropy: 0.2711 - val_tversky_coefficient: 0.7908 - val_iou_coefficient: 0.6566
# Epoch 75/100
# 67/67 [==============================] - 44s 651ms/step - loss: 0.0180 - categorical_crossentropy: 0.1471 - tversky_coefficient: 0.8793 - iou_coefficient: 0.7849 - val_loss: 0.0404 - val_categorical_crossentropy: 0.2226 - val_tversky_coefficient: 0.8307 - val_iou_coefficient: 0.7129
# Epoch 76/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.0180 - categorical_crossentropy: 0.1521 - tversky_coefficient: 0.8749 - iou_coefficient: 0.7779 - val_loss: 0.0218 - val_categorical_crossentropy: 0.1690 - val_tversky_coefficient: 0.8636 - val_iou_coefficient: 0.7618
# Epoch 77/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.0169 - categorical_crossentropy: 0.1459 - tversky_coefficient: 0.8795 - iou_coefficient: 0.7852 - val_loss: 0.0191 - val_categorical_crossentropy: 0.1504 - val_tversky_coefficient: 0.8771 - val_iou_coefficient: 0.7825
# Epoch 78/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.0172 - categorical_crossentropy: 0.1437 - tversky_coefficient: 0.8818 - iou_coefficient: 0.7887 - val_loss: 0.0528 - val_categorical_crossentropy: 0.3016 - val_tversky_coefficient: 0.7703 - val_iou_coefficient: 0.6293
# Epoch 79/100
# 67/67 [==============================] - 44s 657ms/step - loss: 0.0178 - categorical_crossentropy: 0.1507 - tversky_coefficient: 0.8761 - iou_coefficient: 0.7797 - val_loss: 0.0472 - val_categorical_crossentropy: 0.2579 - val_tversky_coefficient: 0.8046 - val_iou_coefficient: 0.6758
# Epoch 80/100
# 67/67 [==============================] - 45s 674ms/step - loss: 0.0176 - categorical_crossentropy: 0.1466 - tversky_coefficient: 0.8795 - iou_coefficient: 0.7852 - val_loss: 0.0224 - val_categorical_crossentropy: 0.1460 - val_tversky_coefficient: 0.8842 - val_iou_coefficient: 0.7942
# Epoch 81/100
# 67/67 [==============================] - 43s 645ms/step - loss: 0.0172 - categorical_crossentropy: 0.1479 - tversky_coefficient: 0.8779 - iou_coefficient: 0.7826 - val_loss: 0.0214 - val_categorical_crossentropy: 0.1889 - val_tversky_coefficient: 0.8448 - val_iou_coefficient: 0.7330
# Epoch 82/100
# 67/67 [==============================] - 46s 687ms/step - loss: 0.0168 - categorical_crossentropy: 0.1427 - tversky_coefficient: 0.8823 - iou_coefficient: 0.7896 - val_loss: 0.0601 - val_categorical_crossentropy: 0.3254 - val_tversky_coefficient: 0.7549 - val_iou_coefficient: 0.6090
# Epoch 83/100
# 67/67 [==============================] - 45s 675ms/step - loss: 0.0169 - categorical_crossentropy: 0.1437 - tversky_coefficient: 0.8816 - iou_coefficient: 0.7886 - val_loss: 0.0201 - val_categorical_crossentropy: 0.1446 - val_tversky_coefficient: 0.8832 - val_iou_coefficient: 0.7921
# Epoch 84/100
# 67/67 [==============================] - 46s 686ms/step - loss: 0.0167 - categorical_crossentropy: 0.1401 - tversky_coefficient: 0.8846 - iou_coefficient: 0.7934 - val_loss: 0.0234 - val_categorical_crossentropy: 0.1884 - val_tversky_coefficient: 0.8472 - val_iou_coefficient: 0.7371
# Epoch 85/100
# 67/67 [==============================] - 45s 662ms/step - loss: 0.0164 - categorical_crossentropy: 0.1418 - tversky_coefficient: 0.8830 - iou_coefficient: 0.7907 - val_loss: 0.0458 - val_categorical_crossentropy: 0.2764 - val_tversky_coefficient: 0.7872 - val_iou_coefficient: 0.6515
# Epoch 86/100
# 67/67 [==============================] - 46s 671ms/step - loss: 0.0172 - categorical_crossentropy: 0.1408 - tversky_coefficient: 0.8845 - iou_coefficient: 0.7932 - val_loss: 0.0217 - val_categorical_crossentropy: 0.1834 - val_tversky_coefficient: 0.8496 - val_iou_coefficient: 0.7397
# Epoch 87/100
# 67/67 [==============================] - 45s 673ms/step - loss: 0.0171 - categorical_crossentropy: 0.1461 - tversky_coefficient: 0.8798 - iou_coefficient: 0.7856 - val_loss: 0.0198 - val_categorical_crossentropy: 0.1569 - val_tversky_coefficient: 0.8723 - val_iou_coefficient: 0.7749
# Epoch 88/100
# 67/67 [==============================] - 45s 662ms/step - loss: 0.0171 - categorical_crossentropy: 0.1438 - tversky_coefficient: 0.8817 - iou_coefficient: 0.7887 - val_loss: 0.0220 - val_categorical_crossentropy: 0.1786 - val_tversky_coefficient: 0.8538 - val_iou_coefficient: 0.7459
# Epoch 89/100
# 67/67 [==============================] - 45s 661ms/step - loss: 0.0180 - categorical_crossentropy: 0.1463 - tversky_coefficient: 0.8801 - iou_coefficient: 0.7862 - val_loss: 0.0644 - val_categorical_crossentropy: 0.2263 - val_tversky_coefficient: 0.8452 - val_iou_coefficient: 0.7337
# Epoch 90/100
# 67/67 [==============================] - 46s 676ms/step - loss: 0.0181 - categorical_crossentropy: 0.1507 - tversky_coefficient: 0.8762 - iou_coefficient: 0.7800 - val_loss: 0.2908 - val_categorical_crossentropy: 0.8051 - val_tversky_coefficient: 0.5103 - val_iou_coefficient: 0.3462
# Epoch 91/100
# 67/67 [==============================] - 47s 693ms/step - loss: 0.0171 - categorical_crossentropy: 0.1457 - tversky_coefficient: 0.8799 - iou_coefficient: 0.7857 - val_loss: 0.0743 - val_categorical_crossentropy: 0.4552 - val_tversky_coefficient: 0.6536 - val_iou_coefficient: 0.4866
# Epoch 92/100
# 67/67 [==============================] - 45s 654ms/step - loss: 0.0166 - categorical_crossentropy: 0.1432 - tversky_coefficient: 0.8817 - iou_coefficient: 0.7887 - val_loss: 0.0694 - val_categorical_crossentropy: 0.3806 - val_tversky_coefficient: 0.7133 - val_iou_coefficient: 0.5563
# Epoch 93/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.0165 - categorical_crossentropy: 0.1411 - tversky_coefficient: 0.8837 - iou_coefficient: 0.7918 - val_loss: 0.0214 - val_categorical_crossentropy: 0.1500 - val_tversky_coefficient: 0.8799 - val_iou_coefficient: 0.7875
# Epoch 94/100
# 67/67 [==============================] - 46s 683ms/step - loss: 0.0167 - categorical_crossentropy: 0.1406 - tversky_coefficient: 0.8843 - iou_coefficient: 0.7928 - val_loss: 0.0210 - val_categorical_crossentropy: 0.1316 - val_tversky_coefficient: 0.8962 - val_iou_coefficient: 0.8135
# Epoch 95/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.0166 - categorical_crossentropy: 0.1406 - tversky_coefficient: 0.8842 - iou_coefficient: 0.7927 - val_loss: 0.0217 - val_categorical_crossentropy: 0.1532 - val_tversky_coefficient: 0.8769 - val_iou_coefficient: 0.7820
# Epoch 96/100
# 67/67 [==============================] - 46s 678ms/step - loss: 0.0158 - categorical_crossentropy: 0.1355 - tversky_coefficient: 0.8881 - iou_coefficient: 0.7990 - val_loss: 0.0198 - val_categorical_crossentropy: 0.1595 - val_tversky_coefficient: 0.8702 - val_iou_coefficient: 0.7720
# Epoch 97/100
# 67/67 [==============================] - 48s 716ms/step - loss: 0.0163 - categorical_crossentropy: 0.1383 - tversky_coefficient: 0.8860 - iou_coefficient: 0.7957 - val_loss: 0.0544 - val_categorical_crossentropy: 0.2859 - val_tversky_coefficient: 0.7852 - val_iou_coefficient: 0.6490
# Epoch 98/100
# 67/67 [==============================] - 48s 706ms/step - loss: 0.0162 - categorical_crossentropy: 0.1371 - tversky_coefficient: 0.8870 - iou_coefficient: 0.7973 - val_loss: 0.0196 - val_categorical_crossentropy: 0.1496 - val_tversky_coefficient: 0.8788 - val_iou_coefficient: 0.7856
# Epoch 99/100
# 67/67 [==============================] - 48s 710ms/step - loss: 0.0169 - categorical_crossentropy: 0.1396 - tversky_coefficient: 0.8855 - iou_coefficient: 0.7947 - val_loss: 0.0449 - val_categorical_crossentropy: 0.3381 - val_tversky_coefficient: 0.7316 - val_iou_coefficient: 0.5775
# Epoch 100/100
# 67/67 [==============================] - 46s 687ms/step - loss: 0.0156 - categorical_crossentropy: 0.1356 - tversky_coefficient: 0.8879 - iou_coefficient: 0.7987 - val_loss: 0.0361 - val_categorical_crossentropy: 0.2637 - val_tversky_coefficient: 0.7901 - val_iou_coefficient: 0.6546

# %% [markdown]
# # Predictions
#
# Only after do we train the models, we can easily produce predicted masks based on the validation set or whatever data that we would like to use, just make sure it is organized as in the train/validation/test sets.

# %%
from glob import glob
from random import sample
from PIL import Image
import numpy as np

def sample_and_plot_predictions(data_path: Path, model_name: str, n=3):
    validation_images = glob(str(data_path/Path("stage1_validation/*")))
    # Sample size
    n_max = len(validation_images)
    n=n_max if n > n_max else n
    validation_images = sample(validation_images, n)
    for img_path in validation_images:
        img_name = img_path.split("/")[-1:][0]
        img = glob(f"{img_path}/images/*.png")[0]
        predictions = glob(f"{img_path}/predicted_masks/{model_name}_predicted_mask.png")[0]
        # Load images
        img_loaded = Image.open(img) 
        predictions_loaded = Image.open(predictions)
        original_size_scaled = (np.array(img_loaded.size)/2).astype(int)
        predictions_scaled = predictions_loaded.resize(original_size_scaled)
        # Plot image and predicted masks
        f, axarr = plt.subplots(1,2)
        plt.title(f"Image and predictions: {img_name}")
        axarr[0].imshow(img_loaded)
        axarr[1].imshow(predictions_scaled)

# %%
# Clean the results of former runs
from glob import glob
from shutil import rmtree
masks = glob(str(data_path/"stage1_validation/**/predicted_*"))
for mask in masks:
    rmtree(mask)

# %%
# When the custom_data_path is set to None, the validation data will be used.
# If that is not the intention of yours, feel free to point the engine to any other direction.
ps.produce_and_save_predicted_masks_for_model(model_name="u_net_plus_plus", custom_data_path=None)
# Out:
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
sample_and_plot_predictions(data_path, model_name="u_net_plus_plus", n=10)

# %%
ps.produce_and_save_predicted_masks_for_model(model_name="res_u_net", custom_data_path=None)
# Out:
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 1s 515ms/step

# %%
sample_and_plot_predictions(data_path, model_name="u_net_plus_plus", n=10)
